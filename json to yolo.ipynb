# %%
import os
import json

# Define the folder containing the JSON files
json_folder = 'E:/dataset'

# Define the folder to store the YOLO annotation files
yolo_folder = 'E:/test'

# Define the class labels and their corresponding IDs
class_labels = {
    'Advance Direction Sign': 0,
    'Bus Stop': 1,
    'Crossroad with a minor ahead': 2,
    'Direction sign (minor routes)': 3,
    'Disabled': 4,
    'Give way': 5,
    'Hospital': 6,
    'Keep Left': 7,
    'Keep Right': 8,
    'Mosque': 9,
    'Narrow bridge ahead': 10,
    'No Entry': 11,
    'No left turn': 12,
    'No Overtaking': 13,
    'NO Parking': 14,
    'No parkingg': 15,
    'No pedestrians': 16,
    'No rickshaws': 17,
    'No rickshaws and Cycles': 18,
    'No right turn': 19,
    'NO Stopping': 20,
    'No trucks': 21,
    'No U turn': 22,
    'No use of horn': 23,
    'One way street': 24,
    'Other danger ahead': 25,
    'Parking': 26,
    'parkingg': 27,
    'Pass either side': 28,
    'Pedestrian Crossing': 29,
    'Railway level crossing with gate or barrier': 30,
    'Reduce Speed': 31,
    'Road hump': 32,
    'School': 33,
    'Sharp bend to the left': 34,
    'Sharp bend to the left ahead': 35,
    'Sharp bend to the right': 36,
    'Sharp bend to the right ahead': 37,
    'Sharp change of multiplayer chevron the right': 38,
    'Side road on the left ahead': 39,
    'Speed limit': 40,
    'Traffic merges from Right': 41,
    'Turn left': 42,
    'Turn Left Ahead': 43,
    'Turn Right': 44,
    'Turn Right Ahead': 45,
    'U-turn': 46
}

# Function to convert bounding box coordinates to YOLO format
def convert_coordinates(xmin, ymin, xmax, ymax, image_width, image_height):
    x = (xmin + xmax) / (2 * image_width)
    y = (ymin + ymax) / (2 * image_height)
    width = (xmax - xmin) / image_width
    height = (ymax - ymin) / image_height
    return x, y, width, height

# Iterate over each folder in the JSON folder
for folder_name in os.listdir(json_folder):
    folder_path = os.path.join(json_folder, folder_name)
    if not os.path.isdir(folder_path):
        continue

    # Create a new folder for YOLO annotations if it doesn't exist
    yolo_subfolder = os.path.join(yolo_folder, folder_name)
    os.makedirs(yolo_subfolder, exist_ok=True)

    # Iterate over each JSON file in the current folder
    for file_name in os.listdir(folder_path):
        if not file_name.endswith('.json'):
            continue

        # Read the JSON file
        json_path = os.path.join(folder_path, file_name)
        with open(json_path) as json_file:
            data = json.load(json_file)

        # Extract image information
        image_name = data['imagePath']
        image_width = data['imageWidth']
        image_height = data['imageHeight']

        # Create a YOLO annotation file
        image_id = os.path.splitext(image_name)[0]
        yolo_file_path = os.path.join(yolo_subfolder, image_id + '.txt')
        with open(yolo_file_path, 'w') as yolo_file:
            # Extract object annotations
            for shape in data['shapes']:
                label = shape['label']
                if label not in class_labels:
                    continue

                class_id = class_labels[label]
                xmin, ymin = shape['points'][0]
                xmax, ymax = shape['points'][1]

                # Convert bounding box coordinates to YOLO format
                x, y, width, height = convert_coordinates(
                    xmin, ymin, xmax, ymax, image_width, image_height)

                # Write the YOLO annotation to the file
                yolo_line = f"{class_id} {x} {y} {width} {height}\n"
                yolo_file.write(yolo_line)

        print(f"Converted {json_path} to YOLO format: {yolo_file_path}")
# Out:
# Converted E:/dataset\Advance Direction Sign\advance road sign detection_0_3022.json to YOLO format: E:/test\Advance Direction Sign\advance road sign detection_0_3022.txt
# Converted E:/dataset\Advance Direction Sign\advance road sign detection_0_4172.json to YOLO format: E:/test\Advance Direction Sign\advance road sign detection_0_4172.txt
# Converted E:/dataset\Advance Direction Sign\advance road sign detection_0_662.json to YOLO format: E:/test\Advance Direction Sign\advance road sign detection_0_662.txt
# Converted E:/dataset\Advance Direction Sign\image (1).json to YOLO format: E:/test\Advance Direction Sign\image (1).txt
# Converted E:/dataset\Advance Direction Sign\image.json to YOLO format: E:/test\Advance Direction Sign\image.txt
# Converted E:/dataset\Bus Stop\1_0_2203.json to YOLO format: E:/test\Bus Stop\1_0_2203.txt
# Converted E:/dataset\Bus Stop\1_0_2787.json to YOLO format: E:/test\Bus Stop\1_0_2787.txt
# Converted E:/dataset\Bus Stop\1_0_4235.json to YOLO format: E:/test\Bus Stop\1_0_4235.txt
# Converted E:/dataset\Bus Stop\1_0_6883.json to YOLO format: E:/test\Bus Stop\1_0_6883.txt
# Converted E:/dataset\Bus Stop\1_0_9589.json to YOLO format: E:/test\Bus Stop\1_0_9589.txt
# Converted E:/dataset\Crossroad with a minor ahead\cross road_0_2095.json to YOLO format: E:/test\Crossroad with a minor ahead\cross road_0_2095.txt
# Converted E:/dataset\Crossroad with a minor ahead\cross road_0_2956.json to YOLO format: E:/test\Crossroad with a minor ahead\cross road_0_2956.txt
# Converted E:/dataset\Crossroad with a minor ahead\cross road_0_4241.json to YOLO format: E:/test\Crossroad with a minor ahead\cross road_0_4241.txt
# Converted E:/dataset\Crossroad with a minor ahead\image (1).json to YOLO format: E:/test\Crossroad with a minor ahead\image (1).txt
# Converted E:/dataset\Crossroad with a minor ahead\image (3).json to YOLO format: E:/test\Crossroad with a minor ahead\image (3).txt
# Converted E:/dataset\Direction sign (minor routes)\direction sign_0_3652.json to YOLO format: E:/test\Direction sign (minor routes)\direction sign_0_3652.txt
# Converted E:/dataset\Direction sign (minor routes)\direction sign_0_4128.json to YOLO format: E:/test\Direction sign (minor routes)\direction sign_0_4128.txt
# Converted E:/dataset\Direction sign (minor routes)\direction sign_0_7701.json to YOLO format: E:/test\Direction sign (minor routes)\direction sign_0_7701.txt
# Converted E:/dataset\Direction sign (minor routes)\image (1).json to YOLO format: E:/test\Direction sign (minor routes)\image (1).txt
# Converted E:/dataset\Disabled\343557449_250290750851740_214579850382903256_n_0_2164.json to YOLO format: E:/test\Disabled\343557449_250290750851740_214579850382903256_n_0_2164.txt
# Converted E:/dataset\Disabled\343557449_250290750851740_214579850382903256_n_0_2631.json to YOLO format: E:/test\Disabled\343557449_250290750851740_214579850382903256_n_0_2631.txt
# Converted E:/dataset\Disabled\343557449_250290750851740_214579850382903256_n_0_6418.json to YOLO format: E:/test\Disabled\343557449_250290750851740_214579850382903256_n_0_6418.txt
# Converted E:/dataset\Disabled\343557449_250290750851740_214579850382903256_n_0_6871.json to YOLO format: E:/test\Disabled\343557449_250290750851740_214579850382903256_n_0_6871.txt
# Converted E:/dataset\Disabled\344239560_133680719693588_3068747947711711055_n.json to YOLO format: E:/test\Disabled\344239560_133680719693588_3068747947711711055_n.txt
# Converted E:/dataset\Give way\give away_0_699.json to YOLO format: E:/test\Give way\give away_0_699.txt
# Converted E:/dataset\Give way\give away_0_7002.json to YOLO format: E:/test\Give way\give away_0_7002.txt
# Converted E:/dataset\Give way\give away_0_8833.json to YOLO format: E:/test\Give way\give away_0_8833.txt
# Converted E:/dataset\Give way\image(2).json to YOLO format: E:/test\Give way\image(2).txt
# Converted E:/dataset\Give way\image(3).json to YOLO format: E:/test\Give way\image(3).txt
# Converted E:/dataset\Hospital\hospital_0_2176.json to YOLO format: E:/test\Hospital\hospital_0_2176.txt
# Converted E:/dataset\Hospital\hospital_0_2876.json to YOLO format: E:/test\Hospital\hospital_0_2876.txt
# Converted E:/dataset\Hospital\hospital_0_4510.json to YOLO format: E:/test\Hospital\hospital_0_4510.txt
# Converted E:/dataset\Hospital\hospital_0_5547.json to YOLO format: E:/test\Hospital\hospital_0_5547.txt
# Converted E:/dataset\Hospital\hospital_0_7980.json to YOLO format: E:/test\Hospital\hospital_0_7980.txt
# Converted E:/dataset\Keep Left\image (4).json to YOLO format: E:/test\Keep Left\image (4).txt
# Converted E:/dataset\Keep Left\keep left_0_1586.json to YOLO format: E:/test\Keep Left\keep left_0_1586.txt
# Converted E:/dataset\Keep Left\keep left_0_2854.json to YOLO format: E:/test\Keep Left\keep left_0_2854.txt
# Converted E:/dataset\Keep Left\keep left_0_4122.json to YOLO format: E:/test\Keep Left\keep left_0_4122.txt
# Converted E:/dataset\Keep Left\keep left_0_618.json to YOLO format: E:/test\Keep Left\keep left_0_618.txt
# Converted E:/dataset\Keep Right\keep right_0_5706.json to YOLO format: E:/test\Keep Right\keep right_0_5706.txt
# Converted E:/dataset\Keep Right\keep right_0_6443.json to YOLO format: E:/test\Keep Right\keep right_0_6443.txt
# Converted E:/dataset\Keep Right\keep right_0_6838.json to YOLO format: E:/test\Keep Right\keep right_0_6838.txt
# Converted E:/dataset\Keep Right\keep right_0_8182.json to YOLO format: E:/test\Keep Right\keep right_0_8182.txt
# Converted E:/dataset\Keep Right\keep right_0_8233.json to YOLO format: E:/test\Keep Right\keep right_0_8233.txt
# Converted E:/dataset\Mosque\mosque_0_3364.json to YOLO format: E:/test\Mosque\mosque_0_3364.txt
# Converted E:/dataset\Mosque\mosque_0_3618.json to YOLO format: E:/test\Mosque\mosque_0_3618.txt
# Converted E:/dataset\Mosque\mosque_0_6422.json to YOLO format: E:/test\Mosque\mosque_0_6422.txt
# Converted E:/dataset\Mosque\mosque_0_6920.json to YOLO format: E:/test\Mosque\mosque_0_6920.txt
# Converted E:/dataset\Mosque\mosque_0_7888.json to YOLO format: E:/test\Mosque\mosque_0_7888.txt
# Converted E:/dataset\Narrow bridge ahead\image(2).json to YOLO format: E:/test\Narrow bridge ahead\image(2).txt
# Converted E:/dataset\Narrow bridge ahead\narrow bridge ahead_0_1304.json to YOLO format: E:/test\Narrow bridge ahead\narrow bridge ahead_0_1304.txt
# Converted E:/dataset\Narrow bridge ahead\narrow bridge ahead_0_3939.json to YOLO format: E:/test\Narrow bridge ahead\narrow bridge ahead_0_3939.txt
# Converted E:/dataset\Narrow bridge ahead\narrow bridge ahead_0_7861.json to YOLO format: E:/test\Narrow bridge ahead\narrow bridge ahead_0_7861.txt
# Converted E:/dataset\Narrow bridge ahead\narrow bridge ahead_0_8956.json to YOLO format: E:/test\Narrow bridge ahead\narrow bridge ahead_0_8956.txt
# Converted E:/dataset\No Entry\image (4).json to YOLO format: E:/test\No Entry\image (4).txt
# Converted E:/dataset\No Entry\no entry_0_1002.json to YOLO format: E:/test\No Entry\no entry_0_1002.txt
# Converted E:/dataset\No Entry\no entry_0_2510.json to YOLO format: E:/test\No Entry\no entry_0_2510.txt
# Converted E:/dataset\No Entry\no entry_0_8279.json to YOLO format: E:/test\No Entry\no entry_0_8279.txt
# Converted E:/dataset\No Entry\no entry_0_8417.json to YOLO format: E:/test\No Entry\no entry_0_8417.txt
# Converted E:/dataset\No left turn\image (2).json to YOLO format: E:/test\No left turn\image (2).txt
# Converted E:/dataset\No left turn\no left turn_0_2331.json to YOLO format: E:/test\No left turn\no left turn_0_2331.txt
# Converted E:/dataset\No left turn\no left turn_0_3114.json to YOLO format: E:/test\No left turn\no left turn_0_3114.txt
# Converted E:/dataset\No left turn\no left turn_0_50.json to YOLO format: E:/test\No left turn\no left turn_0_50.txt
# Converted E:/dataset\No left turn\no left turn_0_8861.json to YOLO format: E:/test\No left turn\no left turn_0_8861.txt
# Converted E:/dataset\No Overtaking\image (4).json to YOLO format: E:/test\No Overtaking\image (4).txt
# Converted E:/dataset\No Overtaking\no overtaking_0_4598.json to YOLO format: E:/test\No Overtaking\no overtaking_0_4598.txt
# Converted E:/dataset\No Overtaking\no overtaking_0_5991.json to YOLO format: E:/test\No Overtaking\no overtaking_0_5991.txt
# Converted E:/dataset\No Overtaking\no overtaking_0_6874.json to YOLO format: E:/test\No Overtaking\no overtaking_0_6874.txt
# Converted E:/dataset\No Overtaking\no overtaking_0_8581.json to YOLO format: E:/test\No Overtaking\no overtaking_0_8581.txt
# Converted E:/dataset\NO Parking\image (1).json to YOLO format: E:/test\NO Parking\image (1).txt
# Converted E:/dataset\NO Parking\image.json to YOLO format: E:/test\NO Parking\image.txt
# Converted E:/dataset\NO Parking\no parking.json to YOLO format: E:/test\NO Parking\no parking.txt
# Converted E:/dataset\NO Parking\no parking_0_6690.json to YOLO format: E:/test\NO Parking\no parking_0_6690.txt
# Converted E:/dataset\NO Parking\no parking_0_8461.json to YOLO format: E:/test\NO Parking\no parking_0_8461.txt
# Converted E:/dataset\No parkingg\12_output_0_2542.json to YOLO format: E:/test\No parkingg\12_output_0_2542.txt
# Converted E:/dataset\No parkingg\12_output_0_7291.json to YOLO format: E:/test\No parkingg\12_output_0_7291.txt
# Converted E:/dataset\No parkingg\12_output_0_7495.json to YOLO format: E:/test\No parkingg\12_output_0_7495.txt
# Converted E:/dataset\No parkingg\12_output_0_8197.json to YOLO format: E:/test\No parkingg\12_output_0_8197.txt
# Converted E:/dataset\No parkingg\12_output_0_8638.json to YOLO format: E:/test\No parkingg\12_output_0_8638.txt
# Converted E:/dataset\No pedestrians\image (2).json to YOLO format: E:/test\No pedestrians\image (2).txt
# Converted E:/dataset\No pedestrians\image.json to YOLO format: E:/test\No pedestrians\image.txt
# Converted E:/dataset\No pedestrians\no padesterian.json to YOLO format: E:/test\No pedestrians\no padesterian.txt
# Converted E:/dataset\No pedestrians\no padesterian_0_5392.json to YOLO format: E:/test\No pedestrians\no padesterian_0_5392.txt
# Converted E:/dataset\No pedestrians\no padesterian_0_8836.json to YOLO format: E:/test\No pedestrians\no padesterian_0_8836.txt
# Converted E:/dataset\No rickshaws\image (1).json to YOLO format: E:/test\No rickshaws\image (1).txt
# Converted E:/dataset\No rickshaws\no rickshaw.json to YOLO format: E:/test\No rickshaws\no rickshaw.txt
# Converted E:/dataset\No rickshaws\no rickshaw_0_1503.json to YOLO format: E:/test\No rickshaws\no rickshaw_0_1503.txt
# Converted E:/dataset\No rickshaws\no rickshaw_0_1621.json to YOLO format: E:/test\No rickshaws\no rickshaw_0_1621.txt
# Converted E:/dataset\No rickshaws\no rickshaw_0_9791.json to YOLO format: E:/test\No rickshaws\no rickshaw_0_9791.txt
# Converted E:/dataset\No rickshaws and Cycles\1.json to YOLO format: E:/test\No rickshaws and Cycles\1.txt
# Converted E:/dataset\No rickshaws and Cycles\no rickshaw and cycle.json to YOLO format: E:/test\No rickshaws and Cycles\no rickshaw and cycle.txt
# Converted E:/dataset\No rickshaws and Cycles\no rickshaw and cycle_0_1078.json to YOLO format: E:/test\No rickshaws and Cycles\no rickshaw and cycle_0_1078.txt
# Converted E:/dataset\No rickshaws and Cycles\no rickshaw and cycle_0_2586.json to YOLO format: E:/test\No rickshaws and Cycles\no rickshaw and cycle_0_2586.txt
# Converted E:/dataset\No rickshaws and Cycles\no rickshaw and cycle_0_9604.json to YOLO format: E:/test\No rickshaws and Cycles\no rickshaw and cycle_0_9604.txt
# Converted E:/dataset\No right turn\1.json to YOLO format: E:/test\No right turn\1.txt
# Converted E:/dataset\No right turn\image (1).json to YOLO format: E:/test\No right turn\image (1).txt
# Converted E:/dataset\No right turn\image (2).json to YOLO format: E:/test\No right turn\image (2).txt
# Converted E:/dataset\No right turn\no right turn_0_6192.json to YOLO format: E:/test\No right turn\no right turn_0_6192.txt
# Converted E:/dataset\No right turn\no right turn_0_9401.json to YOLO format: E:/test\No right turn\no right turn_0_9401.txt
# Converted E:/dataset\NO Stopping\image (3).json to YOLO format: E:/test\NO Stopping\image (3).txt
# Converted E:/dataset\NO Stopping\no stopping_0_2543.json to YOLO format: E:/test\NO Stopping\no stopping_0_2543.txt
# Converted E:/dataset\NO Stopping\no stopping_0_6690.json to YOLO format: E:/test\NO Stopping\no stopping_0_6690.txt
# Converted E:/dataset\NO Stopping\no stopping_0_7065.json to YOLO format: E:/test\NO Stopping\no stopping_0_7065.txt
# Converted E:/dataset\NO Stopping\no stopping_0_8250.json to YOLO format: E:/test\NO Stopping\no stopping_0_8250.txt
# Converted E:/dataset\No trucks\no truck.json to YOLO format: E:/test\No trucks\no truck.txt
# Converted E:/dataset\No trucks\no truck_0_3858.json to YOLO format: E:/test\No trucks\no truck_0_3858.txt
# Converted E:/dataset\No trucks\no truck_0_4427.json to YOLO format: E:/test\No trucks\no truck_0_4427.txt
# Converted E:/dataset\No trucks\no truck_0_4803.json to YOLO format: E:/test\No trucks\no truck_0_4803.txt
# Converted E:/dataset\No trucks\no truck_0_7988.json to YOLO format: E:/test\No trucks\no truck_0_7988.txt
# Converted E:/dataset\No U turn\no u turn_0_4013.json to YOLO format: E:/test\No U turn\no u turn_0_4013.txt
# Converted E:/dataset\No U turn\no u turn_0_8267.json to YOLO format: E:/test\No U turn\no u turn_0_8267.txt
# Converted E:/dataset\No U turn\no u turn_0_8307.json to YOLO format: E:/test\No U turn\no u turn_0_8307.txt
# Converted E:/dataset\No U turn\no u turn_0_8500.json to YOLO format: E:/test\No U turn\no u turn_0_8500.txt
# Converted E:/dataset\No U turn\no u turn_0_8889.json to YOLO format: E:/test\No U turn\no u turn_0_8889.txt
# Converted E:/dataset\No use of horn\image.json to YOLO format: E:/test\No use of horn\image.txt
# Converted E:/dataset\No use of horn\no horn_0_1659.json to YOLO format: E:/test\No use of horn\no horn_0_1659.txt
# Converted E:/dataset\No use of horn\no horn_0_5192.json to YOLO format: E:/test\No use of horn\no horn_0_5192.txt
# Converted E:/dataset\No use of horn\no horn_0_5701.json to YOLO format: E:/test\No use of horn\no horn_0_5701.txt
# Converted E:/dataset\No use of horn\no horn_0_8530.json to YOLO format: E:/test\No use of horn\no horn_0_8530.txt
# Converted E:/dataset\One way street\onne way street.json to YOLO format: E:/test\One way street\onne way street.txt
# Converted E:/dataset\One way street\onne way street_0_1309.json to YOLO format: E:/test\One way street\onne way street_0_1309.txt
# Converted E:/dataset\One way street\onne way street_0_7801.json to YOLO format: E:/test\One way street\onne way street_0_7801.txt
# Converted E:/dataset\One way street\onne way street_0_836.json to YOLO format: E:/test\One way street\onne way street_0_836.txt
# Converted E:/dataset\One way street\onne way street_0_921.json to YOLO format: E:/test\One way street\onne way street_0_921.txt
# Converted E:/dataset\Other danger ahead\image (1).json to YOLO format: E:/test\Other danger ahead\image (1).txt
# Converted E:/dataset\Other danger ahead\other danger ahead.json to YOLO format: E:/test\Other danger ahead\other danger ahead.txt
# Converted E:/dataset\Other danger ahead\other danger ahead_0_6235.json to YOLO format: E:/test\Other danger ahead\other danger ahead_0_6235.txt
# Converted E:/dataset\Other danger ahead\other danger ahead_0_6959.json to YOLO format: E:/test\Other danger ahead\other danger ahead_0_6959.txt
# Converted E:/dataset\Other danger ahead\other danger ahead_0_762.json to YOLO format: E:/test\Other danger ahead\other danger ahead_0_762.txt
# Converted E:/dataset\Parking\parking_0_1423.json to YOLO format: E:/test\Parking\parking_0_1423.txt
# Converted E:/dataset\Parking\parking_0_2078.json to YOLO format: E:/test\Parking\parking_0_2078.txt
# Converted E:/dataset\Parking\parking_0_4026.json to YOLO format: E:/test\Parking\parking_0_4026.txt
# Converted E:/dataset\Parking\parking_0_6356.json to YOLO format: E:/test\Parking\parking_0_6356.txt
# Converted E:/dataset\Parking\parking_0_7094.json to YOLO format: E:/test\Parking\parking_0_7094.txt
# Converted E:/dataset\parkingg\335805220_773855894126897_57262723176839063_n_output_0_5962.json to YOLO format: E:/test\parkingg\335805220_773855894126897_57262723176839063_n_output_0_5962.txt
# Converted E:/dataset\parkingg\335805220_773855894126897_57262723176839063_n_output_0_7585.json to YOLO format: E:/test\parkingg\335805220_773855894126897_57262723176839063_n_output_0_7585.txt
# Converted E:/dataset\parkingg\335805220_773855894126897_57262723176839063_n_output_0_9761.json to YOLO format: E:/test\parkingg\335805220_773855894126897_57262723176839063_n_output_0_9761.txt
# Converted E:/dataset\parkingg\335805220_773855894126897_57262723176839063_n_output_0_9809.json to YOLO format: E:/test\parkingg\335805220_773855894126897_57262723176839063_n_output_0_9809.txt
# Converted E:/dataset\parkingg\image (2).json to YOLO format: E:/test\parkingg\image (2).txt
# Converted E:/dataset\Pass either side\image (1).json to YOLO format: E:/test\Pass either side\image (1).txt
# Converted E:/dataset\Pass either side\pass either side.json to YOLO format: E:/test\Pass either side\pass either side.txt
# Converted E:/dataset\Pass either side\pass either side_0_238.json to YOLO format: E:/test\Pass either side\pass either side_0_238.txt
# Converted E:/dataset\Pass either side\pass either side_0_4471.json to YOLO format: E:/test\Pass either side\pass either side_0_4471.txt
# Converted E:/dataset\Pass either side\pass either side_0_4756.json to YOLO format: E:/test\Pass either side\pass either side_0_4756.txt
# Converted E:/dataset\Pedestrian Crossing\1.json to YOLO format: E:/test\Pedestrian Crossing\1.txt
# Converted E:/dataset\Pedestrian Crossing\image (3).json to YOLO format: E:/test\Pedestrian Crossing\image (3).txt
# Converted E:/dataset\Pedestrian Crossing\padestarian crossing_0_3758.json to YOLO format: E:/test\Pedestrian Crossing\padestarian crossing_0_3758.txt
# Converted E:/dataset\Pedestrian Crossing\padestarian crossing_0_4199.json to YOLO format: E:/test\Pedestrian Crossing\padestarian crossing_0_4199.txt
# Converted E:/dataset\Pedestrian Crossing\padestarian crossing_0_5786.json to YOLO format: E:/test\Pedestrian Crossing\padestarian crossing_0_5786.txt
# Converted E:/dataset\Railway level crossing with gate or barrier\image.json to YOLO format: E:/test\Railway level crossing with gate or barrier\image.txt
# Converted E:/dataset\Railway level crossing with gate or barrier\railway level crossing_0_4440.json to YOLO format: E:/test\Railway level crossing with gate or barrier\railway level crossing_0_4440.txt
# Converted E:/dataset\Railway level crossing with gate or barrier\railway level crossing_0_556.json to YOLO format: E:/test\Railway level crossing with gate or barrier\railway level crossing_0_556.txt
# Converted E:/dataset\Railway level crossing with gate or barrier\railway level crossing_0_7551.json to YOLO format: E:/test\Railway level crossing with gate or barrier\railway level crossing_0_7551.txt
# Converted E:/dataset\Railway level crossing with gate or barrier\railway level crossing_0_8707.json to YOLO format: E:/test\Railway level crossing with gate or barrier\railway level crossing_0_8707.txt
# Converted E:/dataset\Reduce Speed\1.json to YOLO format: E:/test\Reduce Speed\1.txt
# Converted E:/dataset\Reduce Speed\image (4).json to YOLO format: E:/test\Reduce Speed\image (4).txt
# Converted E:/dataset\Reduce Speed\reduse speed_0_1300.json to YOLO format: E:/test\Reduce Speed\reduse speed_0_1300.txt
# Converted E:/dataset\Reduce Speed\reduse speed_0_3639.json to YOLO format: E:/test\Reduce Speed\reduse speed_0_3639.txt
# Converted E:/dataset\Reduce Speed\reduse speed_0_7055.json to YOLO format: E:/test\Reduce Speed\reduse speed_0_7055.txt
# Converted E:/dataset\Road hump\road hump_0_2523.json to YOLO format: E:/test\Road hump\road hump_0_2523.txt
# Converted E:/dataset\Road hump\road hump_0_4244.json to YOLO format: E:/test\Road hump\road hump_0_4244.txt
# Converted E:/dataset\Road hump\road hump_0_4322.json to YOLO format: E:/test\Road hump\road hump_0_4322.txt
# Converted E:/dataset\Road hump\road hump_0_9186.json to YOLO format: E:/test\Road hump\road hump_0_9186.txt
# Converted E:/dataset\Road hump\road hump_0_9189.json to YOLO format: E:/test\Road hump\road hump_0_9189.txt
# Converted E:/dataset\School\image (3).json to YOLO format: E:/test\School\image (3).txt
# Converted E:/dataset\School\school_0_3885.json to YOLO format: E:/test\School\school_0_3885.txt
# Converted E:/dataset\School\school_0_5597.json to YOLO format: E:/test\School\school_0_5597.txt
# Converted E:/dataset\School\school_0_624.json to YOLO format: E:/test\School\school_0_624.txt
# Converted E:/dataset\School\school_0_6922.json to YOLO format: E:/test\School\school_0_6922.txt
# Converted E:/dataset\Sharp bend to the left\1.json to YOLO format: E:/test\Sharp bend to the left\1.txt
# Converted E:/dataset\Sharp bend to the left\sharp bend to left_0_4976.json to YOLO format: E:/test\Sharp bend to the left\sharp bend to left_0_4976.txt
# Converted E:/dataset\Sharp bend to the left\sharp bend to left_0_6303.json to YOLO format: E:/test\Sharp bend to the left\sharp bend to left_0_6303.txt
# Converted E:/dataset\Sharp bend to the left\sharp bend to left_0_6632.json to YOLO format: E:/test\Sharp bend to the left\sharp bend to left_0_6632.txt
# Converted E:/dataset\Sharp bend to the left\sharp bend to left_0_8206.json to YOLO format: E:/test\Sharp bend to the left\sharp bend to left_0_8206.txt
# Converted E:/dataset\Sharp bend to the left ahead\sharp bend to left ahead.json to YOLO format: E:/test\Sharp bend to the left ahead\sharp bend to left ahead.txt
# Converted E:/dataset\Sharp bend to the left ahead\sharp bend to left ahead_0_4532.json to YOLO format: E:/test\Sharp bend to the left ahead\sharp bend to left ahead_0_4532.txt
# Converted E:/dataset\Sharp bend to the left ahead\sharp bend to left ahead_0_5255.json to YOLO format: E:/test\Sharp bend to the left ahead\sharp bend to left ahead_0_5255.txt
# Converted E:/dataset\Sharp bend to the left ahead\sharp bend to left ahead_0_5422.json to YOLO format: E:/test\Sharp bend to the left ahead\sharp bend to left ahead_0_5422.txt
# Converted E:/dataset\Sharp bend to the left ahead\sharp bend to left ahead_0_9045.json to YOLO format: E:/test\Sharp bend to the left ahead\sharp bend to left ahead_0_9045.txt
# Converted E:/dataset\Sharp bend to the right\image (1).json to YOLO format: E:/test\Sharp bend to the right\image (1).txt
# Converted E:/dataset\Sharp bend to the right\image (3).json to YOLO format: E:/test\Sharp bend to the right\image (3).txt
# Converted E:/dataset\Sharp bend to the right\sharp bend to right.json to YOLO format: E:/test\Sharp bend to the right\sharp bend to right.txt
# Converted E:/dataset\Sharp bend to the right\sharp bend to right_0_3879.json to YOLO format: E:/test\Sharp bend to the right\sharp bend to right_0_3879.txt
# Converted E:/dataset\Sharp bend to the right\sharp bend to right_0_4671.json to YOLO format: E:/test\Sharp bend to the right\sharp bend to right_0_4671.txt
# Converted E:/dataset\Sharp bend to the right ahead\sharp bend to rioght ahead_0_6083.json to YOLO format: E:/test\Sharp bend to the right ahead\sharp bend to rioght ahead_0_6083.txt
# Converted E:/dataset\Sharp bend to the right ahead\sharp bend to rioght ahead_0_6178.json to YOLO format: E:/test\Sharp bend to the right ahead\sharp bend to rioght ahead_0_6178.txt
# Converted E:/dataset\Sharp bend to the right ahead\sharp bend to rioght ahead_0_6560(1).json to YOLO format: E:/test\Sharp bend to the right ahead\sharp bend to rioght ahead_0_6560(1).txt
# Converted E:/dataset\Sharp bend to the right ahead\sharp bend to rioght ahead_0_6748.json to YOLO format: E:/test\Sharp bend to the right ahead\sharp bend to rioght ahead_0_6748.txt
# Converted E:/dataset\Sharp bend to the right ahead\sharp bend to rioght ahead_0_8623(1).json to YOLO format: E:/test\Sharp bend to the right ahead\sharp bend to rioght ahead_0_8623(1).txt
# Converted E:/dataset\Sharp change of multiplayer chevron the right\image.json to YOLO format: E:/test\Sharp change of multiplayer chevron the right\image.txt
# Converted E:/dataset\Sharp change of multiplayer chevron the right\Sharp change of multiplayer chevron the right_0_6439.json to YOLO format: E:/test\Sharp change of multiplayer chevron the right\Sharp change of multiplayer chevron the right_0_6439.txt
# Converted E:/dataset\Sharp change of multiplayer chevron the right\Sharp change of multiplayer chevron the right_0_8330(1).json to YOLO format: E:/test\Sharp change of multiplayer chevron the right\Sharp change of multiplayer chevron the right_0_8330(1).txt
# Converted E:/dataset\Sharp change of multiplayer chevron the right\Sharp change of multiplayer chevron the right_0_8688(1).json to YOLO format: E:/test\Sharp change of multiplayer chevron the right\Sharp change of multiplayer chevron the right_0_8688(1).txt
# Converted E:/dataset\Sharp change of multiplayer chevron the right\Sharp change of multiplayer chevron the right_0_8688.json to YOLO format: E:/test\Sharp change of multiplayer chevron the right\Sharp change of multiplayer chevron the right_0_8688.txt
# Converted E:/dataset\Side road on the left ahead\.png.json to YOLO format: E:/test\Side road on the left ahead\.png.txt
# Converted E:/dataset\Side road on the left ahead\image.json to YOLO format: E:/test\Side road on the left ahead\image.txt
# Converted E:/dataset\Side road on the left ahead\side road on the left ahead_0_3382.json to YOLO format: E:/test\Side road on the left ahead\side road on the left ahead_0_3382.txt
# Converted E:/dataset\Side road on the left ahead\side road on the left ahead_0_6079.json to YOLO format: E:/test\Side road on the left ahead\side road on the left ahead_0_6079.txt
# Converted E:/dataset\Side road on the left ahead\side road on the left ahead_0_6505.json to YOLO format: E:/test\Side road on the left ahead\side road on the left ahead_0_6505.txt
# Converted E:/dataset\Speed limit\speed limit_0_3896.json to YOLO format: E:/test\Speed limit\speed limit_0_3896.txt
# Converted E:/dataset\Speed limit\speed limit_0_554.json to YOLO format: E:/test\Speed limit\speed limit_0_554.txt
# Converted E:/dataset\Speed limit\speed limit_0_6667.json to YOLO format: E:/test\Speed limit\speed limit_0_6667.txt
# Converted E:/dataset\Speed limit\speed limit_0_9380.json to YOLO format: E:/test\Speed limit\speed limit_0_9380.txt
# Converted E:/dataset\Traffic merges from Right\image (5).json to YOLO format: E:/test\Traffic merges from Right\image (5).txt
# Converted E:/dataset\Traffic merges from Right\traffic marges from right_0_2474.json to YOLO format: E:/test\Traffic merges from Right\traffic marges from right_0_2474.txt
# Converted E:/dataset\Traffic merges from Right\traffic marges from right_0_2922.json to YOLO format: E:/test\Traffic merges from Right\traffic marges from right_0_2922.txt
# Converted E:/dataset\Traffic merges from Right\traffic marges from right_0_6745.json to YOLO format: E:/test\Traffic merges from Right\traffic marges from right_0_6745.txt
# Converted E:/dataset\Traffic merges from Right\traffic marges from right_0_6881.json to YOLO format: E:/test\Traffic merges from Right\traffic marges from right_0_6881.txt
# Converted E:/dataset\Turn left\image (3).json to YOLO format: E:/test\Turn left\image (3).txt
# Converted E:/dataset\Turn left\turn left_0_3230.json to YOLO format: E:/test\Turn left\turn left_0_3230.txt
# Converted E:/dataset\Turn left\turn left_0_6056.json to YOLO format: E:/test\Turn left\turn left_0_6056.txt
# Converted E:/dataset\Turn left\turn left_0_6714.json to YOLO format: E:/test\Turn left\turn left_0_6714.txt
# Converted E:/dataset\Turn left\turn left_0_7411.json to YOLO format: E:/test\Turn left\turn left_0_7411.txt
# Converted E:/dataset\Turn Left Ahead\turn left ahead_0_1482.json to YOLO format: E:/test\Turn Left Ahead\turn left ahead_0_1482.txt
# Converted E:/dataset\Turn Left Ahead\turn left ahead_0_2467.json to YOLO format: E:/test\Turn Left Ahead\turn left ahead_0_2467.txt
# Converted E:/dataset\Turn Left Ahead\turn left ahead_0_2900.json to YOLO format: E:/test\Turn Left Ahead\turn left ahead_0_2900.txt
# Converted E:/dataset\Turn Left Ahead\turn left ahead_0_6351.json to YOLO format: E:/test\Turn Left Ahead\turn left ahead_0_6351.txt
# Converted E:/dataset\Turn Left Ahead\turn left ahead_0_8374.json to YOLO format: E:/test\Turn Left Ahead\turn left ahead_0_8374.txt
# Converted E:/dataset\Turn Right\image (2).json to YOLO format: E:/test\Turn Right\image (2).txt
# Converted E:/dataset\Turn Right\turrn rright_0_2665.json to YOLO format: E:/test\Turn Right\turrn rright_0_2665.txt
# Converted E:/dataset\Turn Right\turrn rright_0_4419.json to YOLO format: E:/test\Turn Right\turrn rright_0_4419.txt
# Converted E:/dataset\Turn Right\turrn rright_0_7543.json to YOLO format: E:/test\Turn Right\turrn rright_0_7543.txt
# Converted E:/dataset\Turn Right\turrn rright_0_9656.json to YOLO format: E:/test\Turn Right\turrn rright_0_9656.txt
# Converted E:/dataset\Turn Right Ahead\turrn right ahead.json to YOLO format: E:/test\Turn Right Ahead\turrn right ahead.txt
# Converted E:/dataset\Turn Right Ahead\turrn right ahead_0_4985.json to YOLO format: E:/test\Turn Right Ahead\turrn right ahead_0_4985.txt
# Converted E:/dataset\Turn Right Ahead\turrn right ahead_0_532.json to YOLO format: E:/test\Turn Right Ahead\turrn right ahead_0_532.txt
# Converted E:/dataset\Turn Right Ahead\turrn right ahead_0_6913.json to YOLO format: E:/test\Turn Right Ahead\turrn right ahead_0_6913.txt
# Converted E:/dataset\Turn Right Ahead\turrn right ahead_0_747.json to YOLO format: E:/test\Turn Right Ahead\turrn right ahead_0_747.txt
# Converted E:/dataset\U-turn\1.json to YOLO format: E:/test\U-turn\1.txt
# Converted E:/dataset\U-turn\image (2).json to YOLO format: E:/test\U-turn\image (2).txt
# Converted E:/dataset\U-turn\u turn_0_1419.json to YOLO format: E:/test\U-turn\u turn_0_1419.txt
# Converted E:/dataset\U-turn\u turn_0_3483.json to YOLO format: E:/test\U-turn\u turn_0_3483.txt
# Converted E:/dataset\U-turn\u turn_0_7024.json to YOLO format: E:/test\U-turn\u turn_0_7024.txt

# %%
import os
import json
import shutil

# Define the folder containing the JSON files
json_folder = 'E:/dataset'

# Define the folder to store the YOLO annotation files
yolo_folder = 'E:/yolo_v3'

class_labels = {
    'Advance Direction Sign': 0,
    'Bus Stop': 1,
    'Crossroad with a minor ahead': 2,
    'Direction sign (minor routes)': 3,
    'Disabled': 4,
    'Give way': 5,
    'Hospital': 6,
    'Keep Left': 7,
    'Keep Right': 8,
    'Mosque': 9,
    'Narrow bridge ahead': 10,
    'No Entry': 11,
    'No left turn': 12,
    'No Overtaking': 13,
    'NO Parking': 14,
    'No parkingg': 15,
    'No pedestrians': 16,
    'No rickshaws': 17,
    'No rickshaws and Cycles': 18,
    'No right turn': 19,
    'NO Stopping': 20,
    'No trucks': 21,
    'No U turn': 22,
    'No use of horn': 23,
    'One way street': 24,
    'Other danger ahead': 25,
    'Parking': 26,
    'parkingg': 27,
    'Pass either side': 28,
    'Pedestrian Crossing': 29,
    'Railway level crossing with gate or barrier': 30,
    'Reduce Speed': 31,
    'Road hump': 32,
    'School': 33,
    'Sharp bend to the left': 34,
    'Sharp bend to the left ahead': 35,
    'Sharp bend to the right': 36,
    'Sharp bend to the right ahead': 37,
    'Sharp change of multiplayer chevron the right': 38,
    'Side road on the left ahead': 39,
    'Speed limit': 40,
    'Traffic merges from Right': 41,
    'Turn left': 42,
    'Turn Left Ahead': 43,
    'Turn Right': 44,
    'Turn Right Ahead': 45,
    'U-turn': 46
}

# Function to convert bounding box coordinates to YOLO format
def convert_coordinates(xmin, ymin, xmax, ymax, image_width, image_height):
    x = (xmin + xmax) / (2 * image_width)
    y = (ymin + ymax) / (2 * image_height)
    width = (xmax - xmin) / image_width
    height = (ymax - ymin) / image_height
    return x, y, width, height

# Iterate over each folder in the JSON folder
for folder_name in os.listdir(json_folder):
    folder_path = os.path.join(json_folder, folder_name)
    if not os.path.isdir(folder_path):
        continue

    # Create a new folder for YOLO annotations if it doesn't exist
    yolo_subfolder = os.path.join(yolo_folder, folder_name)
    os.makedirs(yolo_subfolder, exist_ok=True)

    # Iterate over each JSON file in the current folder
    for file_name in os.listdir(folder_path):
        if not file_name.endswith('.json'):
            continue

        # Read the JSON file
        json_path = os.path.join(folder_path, file_name)
        with open(json_path) as json_file:
            data = json.load(json_file)

        # Extract image information
        image_name = data['imagePath']
        image_width = data['imageWidth']
        image_height = data['imageHeight']

        # Create a YOLO annotation file
        image_id = os.path.splitext(image_name)[0]
        yolo_file_path = os.path.join(yolo_subfolder, image_id + '.txt')
        with open(yolo_file_path, 'w') as yolo_file:
            # Extract object annotations
            for shape in data['shapes']:
                label = shape['label']
                if label not in class_labels:
                    continue

                class_id = class_labels[label]
                xmin, ymin = shape['points'][0]
                xmax, ymax = shape['points'][1]

                # Convert bounding box coordinates to YOLO format
                x, y, width, height = convert_coordinates(
                    xmin, ymin, xmax, ymax, image_width, image_height)

                # Write the YOLO annotation to the file
                yolo_line = f"{class_id} {x} {y} {width} {height}\n"
                yolo_file.write(yolo_line)

        # Copy or move the image file to the YOLO subfolder
        image_source_path = os.path.join(folder_path, image_name)
        image_dest_path = os.path.join(yolo_subfolder, image_name)
        shutil.copy(image_source_path, image_dest_path)  # Use shutil.move() if you want to move instead of copy

        print(f"Converted {json_path} to YOLO format: {yolo_file_path}")
# Out:
# Converted E:/dataset\Advance Direction Sign\advance road sign detection_0_3022.json to YOLO format: E:/yolo_v3\Advance Direction Sign\advance road sign detection_0_3022.txt
# Converted E:/dataset\Advance Direction Sign\advance road sign detection_0_4172.json to YOLO format: E:/yolo_v3\Advance Direction Sign\advance road sign detection_0_4172.txt
# Converted E:/dataset\Advance Direction Sign\advance road sign detection_0_662.json to YOLO format: E:/yolo_v3\Advance Direction Sign\advance road sign detection_0_662.txt
# Converted E:/dataset\Advance Direction Sign\image (1).json to YOLO format: E:/yolo_v3\Advance Direction Sign\image (1).txt
# Converted E:/dataset\Advance Direction Sign\image.json to YOLO format: E:/yolo_v3\Advance Direction Sign\image.txt
# Converted E:/dataset\Bus Stop\1_0_2203.json to YOLO format: E:/yolo_v3\Bus Stop\1_0_2203.txt
# Converted E:/dataset\Bus Stop\1_0_2787.json to YOLO format: E:/yolo_v3\Bus Stop\1_0_2787.txt
# Converted E:/dataset\Bus Stop\1_0_4235.json to YOLO format: E:/yolo_v3\Bus Stop\1_0_4235.txt
# Converted E:/dataset\Bus Stop\1_0_6883.json to YOLO format: E:/yolo_v3\Bus Stop\1_0_6883.txt
# Converted E:/dataset\Bus Stop\1_0_9589.json to YOLO format: E:/yolo_v3\Bus Stop\1_0_9589.txt
# Converted E:/dataset\Crossroad with a minor ahead\cross road_0_2095.json to YOLO format: E:/yolo_v3\Crossroad with a minor ahead\cross road_0_2095.txt
# Converted E:/dataset\Crossroad with a minor ahead\cross road_0_2956.json to YOLO format: E:/yolo_v3\Crossroad with a minor ahead\cross road_0_2956.txt
# Converted E:/dataset\Crossroad with a minor ahead\cross road_0_4241.json to YOLO format: E:/yolo_v3\Crossroad with a minor ahead\cross road_0_4241.txt
# Converted E:/dataset\Crossroad with a minor ahead\image (1).json to YOLO format: E:/yolo_v3\Crossroad with a minor ahead\image (1).txt
# Converted E:/dataset\Crossroad with a minor ahead\image (3).json to YOLO format: E:/yolo_v3\Crossroad with a minor ahead\image (3).txt
# Converted E:/dataset\Direction sign (minor routes)\direction sign_0_3652.json to YOLO format: E:/yolo_v3\Direction sign (minor routes)\direction sign_0_3652.txt
# Converted E:/dataset\Direction sign (minor routes)\direction sign_0_4128.json to YOLO format: E:/yolo_v3\Direction sign (minor routes)\direction sign_0_4128.txt
# Converted E:/dataset\Direction sign (minor routes)\direction sign_0_7701.json to YOLO format: E:/yolo_v3\Direction sign (minor routes)\direction sign_0_7701.txt
# Converted E:/dataset\Direction sign (minor routes)\image (1).json to YOLO format: E:/yolo_v3\Direction sign (minor routes)\image (1).txt
# Converted E:/dataset\Disabled\343557449_250290750851740_214579850382903256_n_0_2164.json to YOLO format: E:/yolo_v3\Disabled\343557449_250290750851740_214579850382903256_n_0_2164.txt
# Converted E:/dataset\Disabled\343557449_250290750851740_214579850382903256_n_0_2631.json to YOLO format: E:/yolo_v3\Disabled\343557449_250290750851740_214579850382903256_n_0_2631.txt
# Converted E:/dataset\Disabled\343557449_250290750851740_214579850382903256_n_0_6418.json to YOLO format: E:/yolo_v3\Disabled\343557449_250290750851740_214579850382903256_n_0_6418.txt
# Converted E:/dataset\Disabled\343557449_250290750851740_214579850382903256_n_0_6871.json to YOLO format: E:/yolo_v3\Disabled\343557449_250290750851740_214579850382903256_n_0_6871.txt
# Converted E:/dataset\Disabled\344239560_133680719693588_3068747947711711055_n.json to YOLO format: E:/yolo_v3\Disabled\344239560_133680719693588_3068747947711711055_n.txt
# Converted E:/dataset\Give way\give away_0_699.json to YOLO format: E:/yolo_v3\Give way\give away_0_699.txt
# Converted E:/dataset\Give way\give away_0_7002.json to YOLO format: E:/yolo_v3\Give way\give away_0_7002.txt
# Converted E:/dataset\Give way\give away_0_8833.json to YOLO format: E:/yolo_v3\Give way\give away_0_8833.txt
# Converted E:/dataset\Give way\image(2).json to YOLO format: E:/yolo_v3\Give way\image(2).txt
# Converted E:/dataset\Give way\image(3).json to YOLO format: E:/yolo_v3\Give way\image(3).txt
# Converted E:/dataset\Hospital\hospital_0_2176.json to YOLO format: E:/yolo_v3\Hospital\hospital_0_2176.txt
# Converted E:/dataset\Hospital\hospital_0_2876.json to YOLO format: E:/yolo_v3\Hospital\hospital_0_2876.txt
# Converted E:/dataset\Hospital\hospital_0_4510.json to YOLO format: E:/yolo_v3\Hospital\hospital_0_4510.txt
# Converted E:/dataset\Hospital\hospital_0_5547.json to YOLO format: E:/yolo_v3\Hospital\hospital_0_5547.txt
# Converted E:/dataset\Hospital\hospital_0_7980.json to YOLO format: E:/yolo_v3\Hospital\hospital_0_7980.txt
# Converted E:/dataset\Keep Left\image (4).json to YOLO format: E:/yolo_v3\Keep Left\image (4).txt
# Converted E:/dataset\Keep Left\keep left_0_1586.json to YOLO format: E:/yolo_v3\Keep Left\keep left_0_1586.txt
# Converted E:/dataset\Keep Left\keep left_0_2854.json to YOLO format: E:/yolo_v3\Keep Left\keep left_0_2854.txt
# Converted E:/dataset\Keep Left\keep left_0_4122.json to YOLO format: E:/yolo_v3\Keep Left\keep left_0_4122.txt
# Converted E:/dataset\Keep Left\keep left_0_618.json to YOLO format: E:/yolo_v3\Keep Left\keep left_0_618.txt
# Converted E:/dataset\Keep Right\keep right_0_5706.json to YOLO format: E:/yolo_v3\Keep Right\keep right_0_5706.txt
# Converted E:/dataset\Keep Right\keep right_0_6443.json to YOLO format: E:/yolo_v3\Keep Right\keep right_0_6443.txt
# Converted E:/dataset\Keep Right\keep right_0_6838.json to YOLO format: E:/yolo_v3\Keep Right\keep right_0_6838.txt
# Converted E:/dataset\Keep Right\keep right_0_8182.json to YOLO format: E:/yolo_v3\Keep Right\keep right_0_8182.txt
# Converted E:/dataset\Keep Right\keep right_0_8233.json to YOLO format: E:/yolo_v3\Keep Right\keep right_0_8233.txt
# Converted E:/dataset\Mosque\mosque_0_3364.json to YOLO format: E:/yolo_v3\Mosque\mosque_0_3364.txt
# Converted E:/dataset\Mosque\mosque_0_3618.json to YOLO format: E:/yolo_v3\Mosque\mosque_0_3618.txt
# Converted E:/dataset\Mosque\mosque_0_6422.json to YOLO format: E:/yolo_v3\Mosque\mosque_0_6422.txt
# Converted E:/dataset\Mosque\mosque_0_6920.json to YOLO format: E:/yolo_v3\Mosque\mosque_0_6920.txt
# Converted E:/dataset\Mosque\mosque_0_7888.json to YOLO format: E:/yolo_v3\Mosque\mosque_0_7888.txt
# Converted E:/dataset\Narrow bridge ahead\image(2).json to YOLO format: E:/yolo_v3\Narrow bridge ahead\image(2).txt
# Converted E:/dataset\Narrow bridge ahead\narrow bridge ahead_0_1304.json to YOLO format: E:/yolo_v3\Narrow bridge ahead\narrow bridge ahead_0_1304.txt
# Converted E:/dataset\Narrow bridge ahead\narrow bridge ahead_0_3939.json to YOLO format: E:/yolo_v3\Narrow bridge ahead\narrow bridge ahead_0_3939.txt
# Converted E:/dataset\Narrow bridge ahead\narrow bridge ahead_0_7861.json to YOLO format: E:/yolo_v3\Narrow bridge ahead\narrow bridge ahead_0_7861.txt
# Converted E:/dataset\Narrow bridge ahead\narrow bridge ahead_0_8956.json to YOLO format: E:/yolo_v3\Narrow bridge ahead\narrow bridge ahead_0_8956.txt
# Converted E:/dataset\No Entry\image (4).json to YOLO format: E:/yolo_v3\No Entry\image (4).txt
# Converted E:/dataset\No Entry\no entry_0_1002.json to YOLO format: E:/yolo_v3\No Entry\no entry_0_1002.txt
# Converted E:/dataset\No Entry\no entry_0_2510.json to YOLO format: E:/yolo_v3\No Entry\no entry_0_2510.txt
# Converted E:/dataset\No Entry\no entry_0_8279.json to YOLO format: E:/yolo_v3\No Entry\no entry_0_8279.txt
# Converted E:/dataset\No Entry\no entry_0_8417.json to YOLO format: E:/yolo_v3\No Entry\no entry_0_8417.txt
# Converted E:/dataset\No left turn\image (2).json to YOLO format: E:/yolo_v3\No left turn\image (2).txt
# Converted E:/dataset\No left turn\no left turn_0_2331.json to YOLO format: E:/yolo_v3\No left turn\no left turn_0_2331.txt
# Converted E:/dataset\No left turn\no left turn_0_3114.json to YOLO format: E:/yolo_v3\No left turn\no left turn_0_3114.txt
# Converted E:/dataset\No left turn\no left turn_0_50.json to YOLO format: E:/yolo_v3\No left turn\no left turn_0_50.txt
# Converted E:/dataset\No left turn\no left turn_0_8861.json to YOLO format: E:/yolo_v3\No left turn\no left turn_0_8861.txt
# Converted E:/dataset\No Overtaking\image (4).json to YOLO format: E:/yolo_v3\No Overtaking\image (4).txt
# Converted E:/dataset\No Overtaking\no overtaking_0_4598.json to YOLO format: E:/yolo_v3\No Overtaking\no overtaking_0_4598.txt
# Converted E:/dataset\No Overtaking\no overtaking_0_5991.json to YOLO format: E:/yolo_v3\No Overtaking\no overtaking_0_5991.txt
# Converted E:/dataset\No Overtaking\no overtaking_0_6874.json to YOLO format: E:/yolo_v3\No Overtaking\no overtaking_0_6874.txt
# Converted E:/dataset\No Overtaking\no overtaking_0_8581.json to YOLO format: E:/yolo_v3\No Overtaking\no overtaking_0_8581.txt
# Converted E:/dataset\NO Parking\image (1).json to YOLO format: E:/yolo_v3\NO Parking\image (1).txt
# Converted E:/dataset\NO Parking\image.json to YOLO format: E:/yolo_v3\NO Parking\image.txt
# Converted E:/dataset\NO Parking\no parking.json to YOLO format: E:/yolo_v3\NO Parking\no parking.txt
# Converted E:/dataset\NO Parking\no parking_0_6690.json to YOLO format: E:/yolo_v3\NO Parking\no parking_0_6690.txt
# Converted E:/dataset\NO Parking\no parking_0_8461.json to YOLO format: E:/yolo_v3\NO Parking\no parking_0_8461.txt
# Converted E:/dataset\No parkingg\12_output_0_2542.json to YOLO format: E:/yolo_v3\No parkingg\12_output_0_2542.txt
# Converted E:/dataset\No parkingg\12_output_0_7291.json to YOLO format: E:/yolo_v3\No parkingg\12_output_0_7291.txt
# Converted E:/dataset\No parkingg\12_output_0_7495.json to YOLO format: E:/yolo_v3\No parkingg\12_output_0_7495.txt
# Converted E:/dataset\No parkingg\12_output_0_8197.json to YOLO format: E:/yolo_v3\No parkingg\12_output_0_8197.txt
# Converted E:/dataset\No parkingg\12_output_0_8638.json to YOLO format: E:/yolo_v3\No parkingg\12_output_0_8638.txt
# Converted E:/dataset\No pedestrians\image (2).json to YOLO format: E:/yolo_v3\No pedestrians\image (2).txt
# Converted E:/dataset\No pedestrians\image.json to YOLO format: E:/yolo_v3\No pedestrians\image.txt
# Converted E:/dataset\No pedestrians\no padesterian.json to YOLO format: E:/yolo_v3\No pedestrians\no padesterian.txt
# Converted E:/dataset\No pedestrians\no padesterian_0_5392.json to YOLO format: E:/yolo_v3\No pedestrians\no padesterian_0_5392.txt
# Converted E:/dataset\No pedestrians\no padesterian_0_8836.json to YOLO format: E:/yolo_v3\No pedestrians\no padesterian_0_8836.txt
# Converted E:/dataset\No rickshaws\image (1).json to YOLO format: E:/yolo_v3\No rickshaws\image (1).txt
# Converted E:/dataset\No rickshaws\no rickshaw.json to YOLO format: E:/yolo_v3\No rickshaws\no rickshaw.txt
# Converted E:/dataset\No rickshaws\no rickshaw_0_1503.json to YOLO format: E:/yolo_v3\No rickshaws\no rickshaw_0_1503.txt
# Converted E:/dataset\No rickshaws\no rickshaw_0_1621.json to YOLO format: E:/yolo_v3\No rickshaws\no rickshaw_0_1621.txt
# Converted E:/dataset\No rickshaws\no rickshaw_0_9791.json to YOLO format: E:/yolo_v3\No rickshaws\no rickshaw_0_9791.txt
# Converted E:/dataset\No rickshaws and Cycles\1.json to YOLO format: E:/yolo_v3\No rickshaws and Cycles\1.txt
# Converted E:/dataset\No rickshaws and Cycles\no rickshaw and cycle.json to YOLO format: E:/yolo_v3\No rickshaws and Cycles\no rickshaw and cycle.txt
# Converted E:/dataset\No rickshaws and Cycles\no rickshaw and cycle_0_1078.json to YOLO format: E:/yolo_v3\No rickshaws and Cycles\no rickshaw and cycle_0_1078.txt
# Converted E:/dataset\No rickshaws and Cycles\no rickshaw and cycle_0_2586.json to YOLO format: E:/yolo_v3\No rickshaws and Cycles\no rickshaw and cycle_0_2586.txt
# Converted E:/dataset\No rickshaws and Cycles\no rickshaw and cycle_0_9604.json to YOLO format: E:/yolo_v3\No rickshaws and Cycles\no rickshaw and cycle_0_9604.txt
# Converted E:/dataset\No right turn\1.json to YOLO format: E:/yolo_v3\No right turn\1.txt
# Converted E:/dataset\No right turn\image (1).json to YOLO format: E:/yolo_v3\No right turn\image (1).txt
# Converted E:/dataset\No right turn\image (2).json to YOLO format: E:/yolo_v3\No right turn\image (2).txt
# Converted E:/dataset\No right turn\no right turn_0_6192.json to YOLO format: E:/yolo_v3\No right turn\no right turn_0_6192.txt
# Converted E:/dataset\No right turn\no right turn_0_9401.json to YOLO format: E:/yolo_v3\No right turn\no right turn_0_9401.txt
# Converted E:/dataset\NO Stopping\image (3).json to YOLO format: E:/yolo_v3\NO Stopping\image (3).txt
# Converted E:/dataset\NO Stopping\no stopping_0_2543.json to YOLO format: E:/yolo_v3\NO Stopping\no stopping_0_2543.txt
# Converted E:/dataset\NO Stopping\no stopping_0_6690.json to YOLO format: E:/yolo_v3\NO Stopping\no stopping_0_6690.txt
# Converted E:/dataset\NO Stopping\no stopping_0_7065.json to YOLO format: E:/yolo_v3\NO Stopping\no stopping_0_7065.txt
# Converted E:/dataset\NO Stopping\no stopping_0_8250.json to YOLO format: E:/yolo_v3\NO Stopping\no stopping_0_8250.txt
# Converted E:/dataset\No trucks\no truck.json to YOLO format: E:/yolo_v3\No trucks\no truck.txt
# Converted E:/dataset\No trucks\no truck_0_3858.json to YOLO format: E:/yolo_v3\No trucks\no truck_0_3858.txt
# Converted E:/dataset\No trucks\no truck_0_4427.json to YOLO format: E:/yolo_v3\No trucks\no truck_0_4427.txt
# Converted E:/dataset\No trucks\no truck_0_4803.json to YOLO format: E:/yolo_v3\No trucks\no truck_0_4803.txt
# Converted E:/dataset\No trucks\no truck_0_7988.json to YOLO format: E:/yolo_v3\No trucks\no truck_0_7988.txt
# Converted E:/dataset\No U turn\no u turn_0_4013.json to YOLO format: E:/yolo_v3\No U turn\no u turn_0_4013.txt
# Converted E:/dataset\No U turn\no u turn_0_8267.json to YOLO format: E:/yolo_v3\No U turn\no u turn_0_8267.txt
# Converted E:/dataset\No U turn\no u turn_0_8307.json to YOLO format: E:/yolo_v3\No U turn\no u turn_0_8307.txt
# Converted E:/dataset\No U turn\no u turn_0_8500.json to YOLO format: E:/yolo_v3\No U turn\no u turn_0_8500.txt
# Converted E:/dataset\No U turn\no u turn_0_8889.json to YOLO format: E:/yolo_v3\No U turn\no u turn_0_8889.txt
# Converted E:/dataset\No use of horn\image.json to YOLO format: E:/yolo_v3\No use of horn\image.txt
# Converted E:/dataset\No use of horn\no horn_0_1659.json to YOLO format: E:/yolo_v3\No use of horn\no horn_0_1659.txt
# Converted E:/dataset\No use of horn\no horn_0_5192.json to YOLO format: E:/yolo_v3\No use of horn\no horn_0_5192.txt
# Converted E:/dataset\No use of horn\no horn_0_5701.json to YOLO format: E:/yolo_v3\No use of horn\no horn_0_5701.txt
# Converted E:/dataset\No use of horn\no horn_0_8530.json to YOLO format: E:/yolo_v3\No use of horn\no horn_0_8530.txt
# Converted E:/dataset\One way street\onne way street.json to YOLO format: E:/yolo_v3\One way street\onne way street.txt
# Converted E:/dataset\One way street\onne way street_0_1309.json to YOLO format: E:/yolo_v3\One way street\onne way street_0_1309.txt
# Converted E:/dataset\One way street\onne way street_0_7801.json to YOLO format: E:/yolo_v3\One way street\onne way street_0_7801.txt
# Converted E:/dataset\One way street\onne way street_0_836.json to YOLO format: E:/yolo_v3\One way street\onne way street_0_836.txt
# Converted E:/dataset\One way street\onne way street_0_921.json to YOLO format: E:/yolo_v3\One way street\onne way street_0_921.txt
# Converted E:/dataset\Other danger ahead\image (1).json to YOLO format: E:/yolo_v3\Other danger ahead\image (1).txt
# Converted E:/dataset\Other danger ahead\other danger ahead.json to YOLO format: E:/yolo_v3\Other danger ahead\other danger ahead.txt
# Converted E:/dataset\Other danger ahead\other danger ahead_0_6235.json to YOLO format: E:/yolo_v3\Other danger ahead\other danger ahead_0_6235.txt
# Converted E:/dataset\Other danger ahead\other danger ahead_0_6959.json to YOLO format: E:/yolo_v3\Other danger ahead\other danger ahead_0_6959.txt
# Converted E:/dataset\Other danger ahead\other danger ahead_0_762.json to YOLO format: E:/yolo_v3\Other danger ahead\other danger ahead_0_762.txt
# Converted E:/dataset\Parking\parking_0_1423.json to YOLO format: E:/yolo_v3\Parking\parking_0_1423.txt
# Converted E:/dataset\Parking\parking_0_2078.json to YOLO format: E:/yolo_v3\Parking\parking_0_2078.txt
# Converted E:/dataset\Parking\parking_0_4026.json to YOLO format: E:/yolo_v3\Parking\parking_0_4026.txt
# Converted E:/dataset\Parking\parking_0_6356.json to YOLO format: E:/yolo_v3\Parking\parking_0_6356.txt
# Converted E:/dataset\Parking\parking_0_7094.json to YOLO format: E:/yolo_v3\Parking\parking_0_7094.txt
# Converted E:/dataset\parkingg\335805220_773855894126897_57262723176839063_n_output_0_5962.json to YOLO format: E:/yolo_v3\parkingg\335805220_773855894126897_57262723176839063_n_output_0_5962.txt
# Converted E:/dataset\parkingg\335805220_773855894126897_57262723176839063_n_output_0_7585.json to YOLO format: E:/yolo_v3\parkingg\335805220_773855894126897_57262723176839063_n_output_0_7585.txt
# Converted E:/dataset\parkingg\335805220_773855894126897_57262723176839063_n_output_0_9761.json to YOLO format: E:/yolo_v3\parkingg\335805220_773855894126897_57262723176839063_n_output_0_9761.txt
# Converted E:/dataset\parkingg\335805220_773855894126897_57262723176839063_n_output_0_9809.json to YOLO format: E:/yolo_v3\parkingg\335805220_773855894126897_57262723176839063_n_output_0_9809.txt
# Converted E:/dataset\parkingg\image (2).json to YOLO format: E:/yolo_v3\parkingg\image (2).txt
# Converted E:/dataset\Pass either side\image (1).json to YOLO format: E:/yolo_v3\Pass either side\image (1).txt
# Converted E:/dataset\Pass either side\pass either side.json to YOLO format: E:/yolo_v3\Pass either side\pass either side.txt
# Converted E:/dataset\Pass either side\pass either side_0_238.json to YOLO format: E:/yolo_v3\Pass either side\pass either side_0_238.txt
# Converted E:/dataset\Pass either side\pass either side_0_4471.json to YOLO format: E:/yolo_v3\Pass either side\pass either side_0_4471.txt
# Converted E:/dataset\Pass either side\pass either side_0_4756.json to YOLO format: E:/yolo_v3\Pass either side\pass either side_0_4756.txt
# Converted E:/dataset\Pedestrian Crossing\1.json to YOLO format: E:/yolo_v3\Pedestrian Crossing\1.txt
# Converted E:/dataset\Pedestrian Crossing\image (3).json to YOLO format: E:/yolo_v3\Pedestrian Crossing\image (3).txt
# Converted E:/dataset\Pedestrian Crossing\padestarian crossing_0_3758.json to YOLO format: E:/yolo_v3\Pedestrian Crossing\padestarian crossing_0_3758.txt
# Converted E:/dataset\Pedestrian Crossing\padestarian crossing_0_4199.json to YOLO format: E:/yolo_v3\Pedestrian Crossing\padestarian crossing_0_4199.txt
# Converted E:/dataset\Pedestrian Crossing\padestarian crossing_0_5786.json to YOLO format: E:/yolo_v3\Pedestrian Crossing\padestarian crossing_0_5786.txt
# Converted E:/dataset\Railway level crossing with gate or barrier\image.json to YOLO format: E:/yolo_v3\Railway level crossing with gate or barrier\image.txt
# Converted E:/dataset\Railway level crossing with gate or barrier\railway level crossing_0_4440.json to YOLO format: E:/yolo_v3\Railway level crossing with gate or barrier\railway level crossing_0_4440.txt
# Converted E:/dataset\Railway level crossing with gate or barrier\railway level crossing_0_556.json to YOLO format: E:/yolo_v3\Railway level crossing with gate or barrier\railway level crossing_0_556.txt
# Converted E:/dataset\Railway level crossing with gate or barrier\railway level crossing_0_7551.json to YOLO format: E:/yolo_v3\Railway level crossing with gate or barrier\railway level crossing_0_7551.txt
# Converted E:/dataset\Railway level crossing with gate or barrier\railway level crossing_0_8707.json to YOLO format: E:/yolo_v3\Railway level crossing with gate or barrier\railway level crossing_0_8707.txt
# Converted E:/dataset\Reduce Speed\1.json to YOLO format: E:/yolo_v3\Reduce Speed\1.txt
# Converted E:/dataset\Reduce Speed\image (4).json to YOLO format: E:/yolo_v3\Reduce Speed\image (4).txt
# Converted E:/dataset\Reduce Speed\reduse speed_0_1300.json to YOLO format: E:/yolo_v3\Reduce Speed\reduse speed_0_1300.txt
# Converted E:/dataset\Reduce Speed\reduse speed_0_3639.json to YOLO format: E:/yolo_v3\Reduce Speed\reduse speed_0_3639.txt
# Converted E:/dataset\Reduce Speed\reduse speed_0_7055.json to YOLO format: E:/yolo_v3\Reduce Speed\reduse speed_0_7055.txt
# Converted E:/dataset\Road hump\road hump_0_2523.json to YOLO format: E:/yolo_v3\Road hump\road hump_0_2523.txt
# Converted E:/dataset\Road hump\road hump_0_4244.json to YOLO format: E:/yolo_v3\Road hump\road hump_0_4244.txt
# Converted E:/dataset\Road hump\road hump_0_4322.json to YOLO format: E:/yolo_v3\Road hump\road hump_0_4322.txt
# Converted E:/dataset\Road hump\road hump_0_9186.json to YOLO format: E:/yolo_v3\Road hump\road hump_0_9186.txt
# Converted E:/dataset\Road hump\road hump_0_9189.json to YOLO format: E:/yolo_v3\Road hump\road hump_0_9189.txt
# Converted E:/dataset\School\image (3).json to YOLO format: E:/yolo_v3\School\image (3).txt
# Converted E:/dataset\School\school_0_3885.json to YOLO format: E:/yolo_v3\School\school_0_3885.txt
# Converted E:/dataset\School\school_0_5597.json to YOLO format: E:/yolo_v3\School\school_0_5597.txt
# Converted E:/dataset\School\school_0_624.json to YOLO format: E:/yolo_v3\School\school_0_624.txt
# Converted E:/dataset\School\school_0_6922.json to YOLO format: E:/yolo_v3\School\school_0_6922.txt
# Converted E:/dataset\Sharp bend to the left\1.json to YOLO format: E:/yolo_v3\Sharp bend to the left\1.txt
# Converted E:/dataset\Sharp bend to the left\sharp bend to left_0_4976.json to YOLO format: E:/yolo_v3\Sharp bend to the left\sharp bend to left_0_4976.txt
# Converted E:/dataset\Sharp bend to the left\sharp bend to left_0_6303.json to YOLO format: E:/yolo_v3\Sharp bend to the left\sharp bend to left_0_6303.txt
# Converted E:/dataset\Sharp bend to the left\sharp bend to left_0_6632.json to YOLO format: E:/yolo_v3\Sharp bend to the left\sharp bend to left_0_6632.txt
# Converted E:/dataset\Sharp bend to the left\sharp bend to left_0_8206.json to YOLO format: E:/yolo_v3\Sharp bend to the left\sharp bend to left_0_8206.txt
# Converted E:/dataset\Sharp bend to the left ahead\sharp bend to left ahead.json to YOLO format: E:/yolo_v3\Sharp bend to the left ahead\sharp bend to left ahead.txt
# Converted E:/dataset\Sharp bend to the left ahead\sharp bend to left ahead_0_4532.json to YOLO format: E:/yolo_v3\Sharp bend to the left ahead\sharp bend to left ahead_0_4532.txt
# Converted E:/dataset\Sharp bend to the left ahead\sharp bend to left ahead_0_5255.json to YOLO format: E:/yolo_v3\Sharp bend to the left ahead\sharp bend to left ahead_0_5255.txt
# Converted E:/dataset\Sharp bend to the left ahead\sharp bend to left ahead_0_5422.json to YOLO format: E:/yolo_v3\Sharp bend to the left ahead\sharp bend to left ahead_0_5422.txt
# Converted E:/dataset\Sharp bend to the left ahead\sharp bend to left ahead_0_9045.json to YOLO format: E:/yolo_v3\Sharp bend to the left ahead\sharp bend to left ahead_0_9045.txt
# Converted E:/dataset\Sharp bend to the right\image (1).json to YOLO format: E:/yolo_v3\Sharp bend to the right\image (1).txt
# Converted E:/dataset\Sharp bend to the right\image (3).json to YOLO format: E:/yolo_v3\Sharp bend to the right\image (3).txt
# Converted E:/dataset\Sharp bend to the right\sharp bend to right.json to YOLO format: E:/yolo_v3\Sharp bend to the right\sharp bend to right.txt
# Converted E:/dataset\Sharp bend to the right\sharp bend to right_0_3879.json to YOLO format: E:/yolo_v3\Sharp bend to the right\sharp bend to right_0_3879.txt
# Converted E:/dataset\Sharp bend to the right\sharp bend to right_0_4671.json to YOLO format: E:/yolo_v3\Sharp bend to the right\sharp bend to right_0_4671.txt
# Converted E:/dataset\Sharp bend to the right ahead\sharp bend to rioght ahead_0_6083.json to YOLO format: E:/yolo_v3\Sharp bend to the right ahead\sharp bend to rioght ahead_0_6083.txt
# Converted E:/dataset\Sharp bend to the right ahead\sharp bend to rioght ahead_0_6178.json to YOLO format: E:/yolo_v3\Sharp bend to the right ahead\sharp bend to rioght ahead_0_6178.txt
# Converted E:/dataset\Sharp bend to the right ahead\sharp bend to rioght ahead_0_6560(1).json to YOLO format: E:/yolo_v3\Sharp bend to the right ahead\sharp bend to rioght ahead_0_6560(1).txt
# Converted E:/dataset\Sharp bend to the right ahead\sharp bend to rioght ahead_0_6748.json to YOLO format: E:/yolo_v3\Sharp bend to the right ahead\sharp bend to rioght ahead_0_6748.txt
# Converted E:/dataset\Sharp bend to the right ahead\sharp bend to rioght ahead_0_8623(1).json to YOLO format: E:/yolo_v3\Sharp bend to the right ahead\sharp bend to rioght ahead_0_8623(1).txt
# Converted E:/dataset\Sharp change of multiplayer chevron the right\image.json to YOLO format: E:/yolo_v3\Sharp change of multiplayer chevron the right\image.txt
# Converted E:/dataset\Sharp change of multiplayer chevron the right\Sharp change of multiplayer chevron the right_0_6439.json to YOLO format: E:/yolo_v3\Sharp change of multiplayer chevron the right\Sharp change of multiplayer chevron the right_0_6439.txt
# Converted E:/dataset\Sharp change of multiplayer chevron the right\Sharp change of multiplayer chevron the right_0_8330(1).json to YOLO format: E:/yolo_v3\Sharp change of multiplayer chevron the right\Sharp change of multiplayer chevron the right_0_8330(1).txt
# Converted E:/dataset\Sharp change of multiplayer chevron the right\Sharp change of multiplayer chevron the right_0_8688(1).json to YOLO format: E:/yolo_v3\Sharp change of multiplayer chevron the right\Sharp change of multiplayer chevron the right_0_8688(1).txt
# Converted E:/dataset\Sharp change of multiplayer chevron the right\Sharp change of multiplayer chevron the right_0_8688.json to YOLO format: E:/yolo_v3\Sharp change of multiplayer chevron the right\Sharp change of multiplayer chevron the right_0_8688.txt
# Converted E:/dataset\Side road on the left ahead\.png.json to YOLO format: E:/yolo_v3\Side road on the left ahead\.png.txt
# Converted E:/dataset\Side road on the left ahead\image.json to YOLO format: E:/yolo_v3\Side road on the left ahead\image.txt
# Converted E:/dataset\Side road on the left ahead\side road on the left ahead_0_3382.json to YOLO format: E:/yolo_v3\Side road on the left ahead\side road on the left ahead_0_3382.txt
# Converted E:/dataset\Side road on the left ahead\side road on the left ahead_0_6079.json to YOLO format: E:/yolo_v3\Side road on the left ahead\side road on the left ahead_0_6079.txt
# Converted E:/dataset\Side road on the left ahead\side road on the left ahead_0_6505.json to YOLO format: E:/yolo_v3\Side road on the left ahead\side road on the left ahead_0_6505.txt
# Converted E:/dataset\Speed limit\speed limit_0_3896.json to YOLO format: E:/yolo_v3\Speed limit\speed limit_0_3896.txt
# Converted E:/dataset\Speed limit\speed limit_0_554.json to YOLO format: E:/yolo_v3\Speed limit\speed limit_0_554.txt
# Converted E:/dataset\Speed limit\speed limit_0_6667.json to YOLO format: E:/yolo_v3\Speed limit\speed limit_0_6667.txt
# Converted E:/dataset\Speed limit\speed limit_0_9380.json to YOLO format: E:/yolo_v3\Speed limit\speed limit_0_9380.txt
# Converted E:/dataset\Traffic merges from Right\image (5).json to YOLO format: E:/yolo_v3\Traffic merges from Right\image (5).txt
# Converted E:/dataset\Traffic merges from Right\traffic marges from right_0_2474.json to YOLO format: E:/yolo_v3\Traffic merges from Right\traffic marges from right_0_2474.txt
# Converted E:/dataset\Traffic merges from Right\traffic marges from right_0_2922.json to YOLO format: E:/yolo_v3\Traffic merges from Right\traffic marges from right_0_2922.txt
# Converted E:/dataset\Traffic merges from Right\traffic marges from right_0_6745.json to YOLO format: E:/yolo_v3\Traffic merges from Right\traffic marges from right_0_6745.txt
# Converted E:/dataset\Traffic merges from Right\traffic marges from right_0_6881.json to YOLO format: E:/yolo_v3\Traffic merges from Right\traffic marges from right_0_6881.txt
# Converted E:/dataset\Turn left\image (3).json to YOLO format: E:/yolo_v3\Turn left\image (3).txt
# Converted E:/dataset\Turn left\turn left_0_3230.json to YOLO format: E:/yolo_v3\Turn left\turn left_0_3230.txt
# Converted E:/dataset\Turn left\turn left_0_6056.json to YOLO format: E:/yolo_v3\Turn left\turn left_0_6056.txt
# Converted E:/dataset\Turn left\turn left_0_6714.json to YOLO format: E:/yolo_v3\Turn left\turn left_0_6714.txt
# Converted E:/dataset\Turn left\turn left_0_7411.json to YOLO format: E:/yolo_v3\Turn left\turn left_0_7411.txt
# Converted E:/dataset\Turn Left Ahead\turn left ahead_0_1482.json to YOLO format: E:/yolo_v3\Turn Left Ahead\turn left ahead_0_1482.txt
# Converted E:/dataset\Turn Left Ahead\turn left ahead_0_2467.json to YOLO format: E:/yolo_v3\Turn Left Ahead\turn left ahead_0_2467.txt
# Converted E:/dataset\Turn Left Ahead\turn left ahead_0_2900.json to YOLO format: E:/yolo_v3\Turn Left Ahead\turn left ahead_0_2900.txt
# Converted E:/dataset\Turn Left Ahead\turn left ahead_0_6351.json to YOLO format: E:/yolo_v3\Turn Left Ahead\turn left ahead_0_6351.txt
# Converted E:/dataset\Turn Left Ahead\turn left ahead_0_8374.json to YOLO format: E:/yolo_v3\Turn Left Ahead\turn left ahead_0_8374.txt
# Converted E:/dataset\Turn Right\image (2).json to YOLO format: E:/yolo_v3\Turn Right\image (2).txt
# Converted E:/dataset\Turn Right\turrn rright_0_2665.json to YOLO format: E:/yolo_v3\Turn Right\turrn rright_0_2665.txt
# Converted E:/dataset\Turn Right\turrn rright_0_4419.json to YOLO format: E:/yolo_v3\Turn Right\turrn rright_0_4419.txt
# Converted E:/dataset\Turn Right\turrn rright_0_7543.json to YOLO format: E:/yolo_v3\Turn Right\turrn rright_0_7543.txt
# Converted E:/dataset\Turn Right\turrn rright_0_9656.json to YOLO format: E:/yolo_v3\Turn Right\turrn rright_0_9656.txt
# Converted E:/dataset\Turn Right Ahead\turrn right ahead.json to YOLO format: E:/yolo_v3\Turn Right Ahead\turrn right ahead.txt
# Converted E:/dataset\Turn Right Ahead\turrn right ahead_0_4985.json to YOLO format: E:/yolo_v3\Turn Right Ahead\turrn right ahead_0_4985.txt
# Converted E:/dataset\Turn Right Ahead\turrn right ahead_0_532.json to YOLO format: E:/yolo_v3\Turn Right Ahead\turrn right ahead_0_532.txt
# Converted E:/dataset\Turn Right Ahead\turrn right ahead_0_6913.json to YOLO format: E:/yolo_v3\Turn Right Ahead\turrn right ahead_0_6913.txt
# Converted E:/dataset\Turn Right Ahead\turrn right ahead_0_747.json to YOLO format: E:/yolo_v3\Turn Right Ahead\turrn right ahead_0_747.txt
# Converted E:/dataset\U-turn\1.json to YOLO format: E:/yolo_v3\U-turn\1.txt
# Converted E:/dataset\U-turn\image (2).json to YOLO format: E:/yolo_v3\U-turn\image (2).txt
# Converted E:/dataset\U-turn\u turn_0_1419.json to YOLO format: E:/yolo_v3\U-turn\u turn_0_1419.txt
# Converted E:/dataset\U-turn\u turn_0_3483.json to YOLO format: E:/yolo_v3\U-turn\u turn_0_3483.txt
# Converted E:/dataset\U-turn\u turn_0_7024.json to YOLO format: E:/yolo_v3\U-turn\u turn_0_7024.txt
